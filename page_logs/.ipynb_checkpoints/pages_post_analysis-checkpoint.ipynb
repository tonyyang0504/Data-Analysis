# %%
import pandas as pd
import os

# %% [markdown]
# #### 此次主要分析主页发帖任务中，出现错误发帖占总发帖的比例以及不同错误的分布情况，并以表格和图的形式展现结果，首先载入并处理数据。

# %%
files = [x for x in os.listdir('.') if x.endswith('.csv')]

error_rate_dict = {}
error_distribution_to_total_dict = {}
error_distribution_dict = {}
total_count_dict = {}
error_count_dict = {}

for file in files:
    name = file.split('.csv')[0]
    df = pd.read_csv(file)
    publishing_error = df[df['Status'].str.contains('Error publishing a Post')]
    publishing_total = df[df['Status'].str.contains('\*FINALIZED\* a post')]
    
    total_count = publishing_total.Status.count()
    error_count = publishing_error.Status.count()
    error_rate = round(error_count / total_count, 2)
    
    publishing_error = publishing_error.copy()
    publishing_error['Code'] = publishing_error['Status'].apply(lambda x: x.split(',')[0].split(':')[1].split('-')[0])
    
    code_count = publishing_error.groupby(['Code'])['Status'].count()
    
    error_rate_dict[name] = error_rate
    total_count_dict[name] = total_count
    error_count_dict[name] = error_count
    error_distribution_dict[name] = code_count / publishing_error['Code'].count()
    error_distribution_to_total_dict[name] = code_count / publishing_total['Status'].count()

# %%
files
# Out:
# ['151.106.35.202 U43_page_post_logs_tony.csv',
#  '151.106.35.221 U43_pages_post_logs_tony.csv',
#  '151_106_42_145GEN_R49_pages_post_logs_aidan.csv',
#  '18U45-10 page_post_logs_aaron.csv',
#  'b8 151.106.41.12  page_post_logs_cary.csv']

# %%
group_joiner_dict = {}

for file in files:
    name = file.split('.csv')[0]
    df = pd.read_csv(file)
    
    filter_finished = df[df['Status'].str.contains('Group Joiner') & df['Status'].str.contains('Finished operation')]
    filter_error = df[df['Status'].str.contains('Group Joiner') & df['Status'].str.contains('Error')]
    
    df_finished_count = df_finished.groupby('Account')['Status'].count()
    df_error_count = df_error.groupby('Account')['Status'].count()
    
    df_total_count = pd.concat([df_finished_count, df_error_count], axis=1).fillna(0)
    df_total_count.columns = ['Finished Amount', 'Error Amount']
    df_total_count['Total Amount'] = df_total_count.sum(1)
    df_total_count['Success Rate'] = df_total_count['Finished Amount'] / df_total_count['Total Amount']
    
    group_joiner_dict[name] = df_total_count

# %%
group_joiner_dict
# Out:
# {'151.106.35.202 U43_page_post_logs_tony':                 Finished Amount  Error Amount  Total Amount  Success Rate
#  Gen_Malaysia1               3.0          26.0          29.0      0.103448
#  Gen_Malaysia11              3.0          24.0          27.0      0.111111
#  Gen_Malaysia12             29.0           0.0          29.0      1.000000
#  Gen_Malaysia13             29.0           0.0          29.0      1.000000
#  Gen_Malaysia14              3.0          19.0          22.0      0.136364
#  ...                         ...           ...           ...           ...
#  Gen_Malaysia8               3.0          29.0          32.0      0.093750
#  Gen_Malaysia9              29.0           0.0          29.0      1.000000
#  Gen_Malaysia10              0.0          17.0          17.0      0.000000
#  Gen_Malaysia25              0.0          72.0          72.0      0.000000
#  Gen_Malaysia58              0.0          17.0          17.0      0.000000
#
#  [67 rows x 4 columns],
#  '151.106.35.221 U43_pages_post_logs_tony':                Finished Amount  Error Amount  Total Amount  Success Rate
#  AJ_Malaysia1              29.0           0.0          29.0      1.000000
#  AJ_Malaysia10             29.0           4.0          33.0      0.878788
#  AJ_Malaysia11             29.0           0.0          29.0      1.000000
#  AJ_Malaysia12             29.0           0.0          29.0      1.000000
#  AJ_Malaysia13             29.0           0.0          29.0      1.000000
#  ...                        ...           ...           ...           ...
#  AJ_Malaysia31              0.0          67.0          67.0      0.000000
#  AJ_Malaysia4               0.0          71.0          71.0      0.000000
#  AJ_Malaysia50              0.0          71.0          71.0      0.000000
#  AJ_Malaysia66              0.0          71.0          71.0      0.000000
#  AJ_Malaysia7               0.0          72.0          72.0      0.000000
#
#  [70 rows x 4 columns],
#  '151_106_42_145GEN_R49_pages_post_logs_aidan':                 Finished Amount  Error Amount  Total Amount  Success Rate
#  Gen_Malaysia1                36           1.0          37.0      0.972973
#  Gen_Malaysia10               31           6.0          37.0      0.837838
#  Gen_Malaysia11               35           0.0          35.0      1.000000
#  Gen_Malaysia12               32           1.0          33.0      0.969697
#  Gen_Malaysia13               30           0.0          30.0      1.000000
#  ...                         ...           ...           ...           ...
#  Gen_Malaysia69               34           0.0          34.0      1.000000
#  Gen_Malaysia7                35           0.0          35.0      1.000000
#  Gen_Malaysia70               37           0.0          37.0      1.000000
#  Gen_Malaysia8                35           4.0          39.0      0.897436
#  Gen_Malaysia9                 9          27.0          36.0      0.250000
#
#  [67 rows x 4 columns],
#  '18U45-10 page_post_logs_aaron':                    Finished Amount  Error Amount  Total Amount  Success Rate
#  Cia_Malaysia_1051             33.0          27.0          60.0      0.550000
#  Cia_Malaysia_1085             43.0           0.0          43.0      1.000000
#  Cia_Malaysia_1086             22.0          34.0          56.0      0.392857
#  Cia_Malaysia_1088             41.0           0.0          41.0      1.000000
#  Cia_Malaysia_1090             49.0           0.0          49.0      1.000000
#  Cia_Malaysia_1093              2.0          85.0          87.0      0.022989
#  Cia_Malaysia_1094             48.0           0.0          48.0      1.000000
#  Cia_Malaysia_1105             36.0           0.0          36.0      1.000000
#  Cia_Malaysia_1106              3.0          42.0          45.0      0.066667
#  Cia_Malaysia_1107             45.0           1.0          46.0      0.978261
#  Cia_Malaysia_1108             40.0           0.0          40.0      1.000000
#  Cia_Malaysia_1110             49.0           0.0          49.0      1.000000
#  Cia_Malaysia_1111             50.0           0.0          50.0      1.000000
#  Cia_Malaysia_1112             43.0           0.0          43.0      1.000000
#  Cia_Malaysia_1113             33.0           9.0          42.0      0.785714
#  Cia_Malaysia_1114             35.0          13.0          48.0      0.729167
#  Cia_Malaysia_1115             43.0           0.0          43.0      1.000000
#  Cia_Malaysia_1116             40.0           1.0          41.0      0.975610
#  Cia_Malaysia_1117             25.0           3.0          28.0      0.892857
#  Cia_Malaysia_1096              0.0          83.0          83.0      0.000000,
#  'b8 151.106.41.12  page_post_logs_cary':                      Finished Amount  Error Amount  Total Amount  Success Rate
#  Oliver_Malaysia_421            100.0           0.0         100.0      1.000000
#  Oliver_Malaysia_422            134.0           2.0         136.0      0.985294
#  Oliver_Malaysia_423            147.0           0.0         147.0      1.000000
#  Oliver_Malaysia_424            147.0           1.0         148.0      0.993243
#  Oliver_Malaysia_425            140.0           0.0         140.0      1.000000
#  ...                              ...           ...           ...           ...
#  Oliver_Malaysia_487            100.0           0.0         100.0      1.000000
#  Oliver_Malaysia_488            100.0           0.0         100.0      1.000000
#  Oliver_Malaysia_489            100.0           0.0         100.0      1.000000
#  Oliver_Malaysia_490             78.0         428.0         506.0      0.154150
#  Oliver_Malaysia_470              0.0         569.0         569.0      0.000000
#
#  [70 rows x 4 columns]}

# %%
data_list = [key for key in group_joiner_dict.keys()]

# %%
for
# Out:
# ['151.106.35.202 U43_page_post_logs_tony',
#  '151.106.35.221 U43_pages_post_logs_tony',
#  '151_106_42_145GEN_R49_pages_post_logs_aidan',
#  '18U45-10 page_post_logs_aaron',
#  'b8 151.106.41.12  page_post_logs_cary']

# %%
group_joiner_data = pd.concat(data_list)

# %%
group_joiner_data
# Out:
#                      Finished Amount  Error Amount  Total Amount  Success Rate
# Gen_Malaysia1                    3.0          26.0          29.0      0.103448
# Gen_Malaysia11                   3.0          24.0          27.0      0.111111
# Gen_Malaysia12                  29.0           0.0          29.0      1.000000
# Gen_Malaysia13                  29.0           0.0          29.0      1.000000
# Gen_Malaysia14                   3.0          19.0          22.0      0.136364
# ...                              ...           ...           ...           ...
# Oliver_Malaysia_487            100.0           0.0         100.0      1.000000
# Oliver_Malaysia_488            100.0           0.0         100.0      1.000000
# Oliver_Malaysia_489            100.0           0.0         100.0      1.000000
# Oliver_Malaysia_490             78.0         428.0         506.0      0.154150
# Oliver_Malaysia_470              0.0         569.0         569.0      0.000000
#
# [294 rows x 4 columns]

# %%
group_joiner_data.describe()
# Out:
#        Finished Amount  Error Amount  Total Amount  Success Rate
# count       294.000000    294.000000    294.000000    294.000000
# mean         47.159864     32.517007     79.676871      0.764662
# std          44.874778     97.964426    115.739620      0.367005
# min           0.000000      0.000000     11.000000      0.000000
# 25%          28.250000      0.000000     29.000000      0.500000
# 50%          29.000000      0.000000     33.000000      1.000000
# 75%          43.000000     14.000000     76.750000      1.000000
# max         147.000000    573.000000    604.000000      1.000000

# %%
success_rate_data = pd.DataFrame(group_joiner_data['Success Rate'])

# %%
success_rate_data
# Out:
#                      Success Rate
# Gen_Malaysia1            0.103448
# Gen_Malaysia11           0.111111
# Gen_Malaysia12           1.000000
# Gen_Malaysia13           1.000000
# Gen_Malaysia14           0.136364
# ...                           ...
# Oliver_Malaysia_487      1.000000
# Oliver_Malaysia_488      1.000000
# Oliver_Malaysia_489      1.000000
# Oliver_Malaysia_490      0.154150
# Oliver_Malaysia_470      0.000000
#
# [294 rows x 1 columns]

# %%
success_rate_data.plot(kind='hist', figsize=(16, 8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
group_joiner_error_dict
# Out:
# {'151.106.35.202 U43_page_post_logs_tony':                      Date         Account  \
#  986   09/28/2022 15:27:33  Gen_Malaysia25
#  1014  09/28/2022 15:38:15  Gen_Malaysia58
#  1044  09/28/2022 15:46:24  Gen_Malaysia10
#  1072  09/28/2022 15:54:15  Gen_Malaysia58
#  1092  09/28/2022 16:00:07  Gen_Malaysia25
#  ...                   ...             ...
#  6210  09/30/2022 22:27:24  Gen_Malaysia26
#  6212  09/30/2022 22:44:24  Gen_Malaysia25
#  6214  09/30/2022 22:47:02  Gen_Malaysia26
#  6216  09/30/2022 23:06:47  Gen_Malaysia26
#  6218  09/30/2022 23:14:19  Gen_Malaysia25
#
#                                                   Status
#  986   Group Joiner - Error executing for the 'Gen_Ma...
#  1014  Group Joiner - Error executing for the 'Gen_Ma...
#  1044  Group Joiner - Error executing for the 'Gen_Ma...
#  1072  Group Joiner - Error executing for the 'Gen_Ma...
#  1092  Group Joiner - Error executing for the 'Gen_Ma...
#  ...                                                 ...
#  6210  Group Joiner - Error executing for the 'Gen_Ma...
#  6212  Group Joiner - Error executing for the 'Gen_Ma...
#  6214  Group Joiner - Error executing for the 'Gen_Ma...
#  6216  Group Joiner - Error executing for the 'Gen_Ma...
#  6218  Group Joiner - Error executing for the 'Gen_Ma...
#
#  [611 rows x 3 columns],
#  '151.106.35.221 U43_pages_post_logs_tony':                      Date        Account  \
#  346   09/28/2022 15:24:25   AJ_Malaysia7
#  364   09/28/2022 15:33:29  AJ_Malaysia23
#  371   09/28/2022 15:36:37  AJ_Malaysia25
#  374   09/28/2022 15:37:53   AJ_Malaysia3
#  398   09/28/2022 15:50:32  AJ_Malaysia50
#  ...                   ...            ...
#  7128  09/30/2022 23:07:33  AJ_Malaysia23
#  7129  09/30/2022 23:07:33   AJ_Malaysia7
#  7133  09/30/2022 23:11:11  AJ_Malaysia25
#  7134  09/30/2022 23:11:36  AJ_Malaysia50
#  7207  09/30/2022 23:13:02  AJ_Malaysia57
#
#                                                   Status
#  346   Group Joiner - Error executing for the 'AJ_Mal...
#  364   Group Joiner - Error executing for the 'AJ_Mal...
#  371   Group Joiner - Error executing for the 'AJ_Mal...
#  374   Group Joiner - Error executing for the 'AJ_Mal...
#  398   Group Joiner - Error executing for the 'AJ_Mal...
#  ...                                                 ...
#  7128  Group Joiner - Error executing for the 'AJ_Mal...
#  7129  Group Joiner - Error executing for the 'AJ_Mal...
#  7133  Group Joiner - Error executing for the 'AJ_Mal...
#  7134  Group Joiner - Error executing for the 'AJ_Mal...
#  7207  Group Joiner - Error executing for the 'AJ_Mal...
#
#  [913 rows x 3 columns],
#  '151_106_42_145GEN_R49_pages_post_logs_aidan':                      Date         Account  \
#  406   09/28/2022 09:51:11  Gen_Malaysia15
#  546   09/28/2022 10:50:45  Gen_Malaysia19
#  552   09/28/2022 10:51:43  Gen_Malaysia15
#  583   09/28/2022 11:42:29   Gen_Malaysia5
#  585   09/28/2022 11:42:33  Gen_Malaysia24
#  ...                   ...             ...
#  6104  09/30/2022 06:08:18  Gen_Malaysia33
#  6123  09/30/2022 06:10:07  Gen_Malaysia47
#  6125  09/30/2022 06:10:13  Gen_Malaysia67
#  6151  09/30/2022 06:12:49   Gen_Malaysia9
#  6171  09/30/2022 06:14:36   Gen_Malaysia3
#
#                                                   Status
#  406   Group Joiner - Error executing for the 'Gen_Ma...
#  546   Group Joiner - Error executing for the 'Gen_Ma...
#  552   Group Joiner - Error executing for the 'Gen_Ma...
#  583   Group Joiner - Error executing for the 'Gen_Ma...
#  585   Group Joiner - Error executing for the 'Gen_Ma...
#  ...                                                 ...
#  6104  Group Joiner - Error executing for the 'Gen_Ma...
#  6123  Group Joiner - Error executing for the 'Gen_Ma...
#  6125  Group Joiner - Error executing for the 'Gen_Ma...
#  6151  Group Joiner - Error executing for the 'Gen_Ma...
#  6171  Group Joiner - Error executing for the 'Gen_Ma...
#
#  [368 rows x 3 columns],
#  '18U45-10 page_post_logs_aaron':                      Date            Account  \
#  3180  09/27/2022 07:41:17  Cia_Malaysia_1096
#  3212  09/27/2022 08:14:54  Cia_Malaysia_1096
#  3264  09/27/2022 09:06:05  Cia_Malaysia_1096
#  3268  09/27/2022 09:08:06  Cia_Malaysia_1093
#  3279  09/27/2022 09:13:38  Cia_Malaysia_1051
#  ...                   ...                ...
#  6471  09/29/2022 21:28:12  Cia_Malaysia_1093
#  6479  09/29/2022 22:00:38  Cia_Malaysia_1093
#  6491  09/29/2022 22:19:08  Cia_Malaysia_1096
#  6503  09/29/2022 23:12:06  Cia_Malaysia_1096
#  6505  09/29/2022 23:16:15  Cia_Malaysia_1093
#
#                                                   Status
#  3180  Group Joiner - Error executing for the 'Cia_Ma...
#  3212  Group Joiner - Error executing for the 'Cia_Ma...
#  3264  Group Joiner - Error executing for the 'Cia_Ma...
#  3268  Group Joiner - Error executing for the 'Cia_Ma...
#  3279  Group Joiner - Error executing for the 'Cia_Ma...
#  ...                                                 ...
#  6471  Group Joiner - Error executing for the 'Cia_Ma...
#  6479  Group Joiner - Error executing for the 'Cia_Ma...
#  6491  Group Joiner - Error executing for the 'Cia_Ma...
#  6503  Group Joiner - Error executing for the 'Cia_Ma...
#  6505  Group Joiner - Error executing for the 'Cia_Ma...
#
#  [298 rows x 3 columns],
#  'b8 151.106.41.12  page_post_logs_cary':                       Date              Account  \
#  420    09/08/2022 07:19:28  Oliver_Malaysia_445
#  429    09/08/2022 07:21:00  Oliver_Malaysia_470
#  445    09/08/2022 07:24:49  Oliver_Malaysia_473
#  465    09/08/2022 07:29:20  Oliver_Malaysia_428
#  536    09/08/2022 08:02:11  Oliver_Malaysia_422
#  ...                    ...                  ...
#  32721  09/29/2022 04:17:26  Oliver_Malaysia_435
#  32724  09/29/2022 04:19:13  Oliver_Malaysia_472
#  32728  09/29/2022 04:21:13  Oliver_Malaysia_431
#  32729  09/29/2022 04:21:34  Oliver_Malaysia_430
#  32744  09/29/2022 04:25:02  Oliver_Malaysia_443
#
#                                                    Status
#  420    Group Joiner - Error executing for the 'Oliver...
#  429    Group Joiner - Error executing for the 'Oliver...
#  445    Group Joiner - Error executing for the 'Oliver...
#  465    Group Joiner - Error executing for the 'Oliver...
#  536    Group Joiner - Error executing for the 'Oliver...
#  ...                                                  ...
#  32721  Group Joiner - Error executing for the 'Oliver...
#  32724  Group Joiner - Error executing for the 'Oliver...
#  32728  Group Joiner - Error executing for the 'Oliver...
#  32729  Group Joiner - Error executing for the 'Oliver...
#  32744  Group Joiner - Error executing for the 'Oliver...
#
#  [7370 rows x 3 columns]}

# %% [markdown]
# #### 接下来将每个发帖活动的总发帖数量、总错误量、错误率以表格的形式展现，并计算各自的统计数据。

# %%
count_data = pd.DataFrame([total_count_dict, error_count_dict, error_rate_dict],
                                index=['number of post', 'number of error', 'error rate']).T
count_data
# Out:
#                                              number of post  number of error  \
# 151.106.35.202 U43_page_post_logs_tony                946.0            504.0
# 151.106.35.221 U43_pages_post_logs_tony              1672.0            791.0
# 151_106_42_145GEN_R49_pages_post_logs_aidan          1528.0            886.0
# 18U45-10 page_post_logs_aaron                         252.0            130.0
# b8 151.106.41.12  page_post_logs_cary                 647.0            377.0
#
#                                              error rate
# 151.106.35.202 U43_page_post_logs_tony             0.53
# 151.106.35.221 U43_pages_post_logs_tony            0.47
# 151_106_42_145GEN_R49_pages_post_logs_aidan        0.58
# 18U45-10 page_post_logs_aaron                      0.52
# b8 151.106.41.12  page_post_logs_cary              0.58

# %%
count_data.describe()
# Out:
#        number of post  number of error  error rate
# count        5.000000         5.000000    5.000000
# mean      1009.000000       537.600000    0.536000
# std        595.187365       307.674016    0.046152
# min        252.000000       130.000000    0.470000
# 25%        647.000000       377.000000    0.520000
# 50%        946.000000       504.000000    0.530000
# 75%       1528.000000       791.000000    0.580000
# max       1672.000000       886.000000    0.580000

# %% [markdown]
# #### 下面计算所有发帖活动的发帖总量和错误总量，并将每个发帖活动的错误率数据可视化。

# %%
count_data.iloc[:,0:2].sum()
# Out:
# number of post     5045.0
# number of error    2688.0
# dtype: float64

# %%
error_rate_data = pd.DataFrame(error_rate_dict, index=['error rate'])
error_rate_plot = error_rate_data.plot(kind='bar', figsize=(16, 8), title='error rate', rot=True)

# %% [markdown]
# #### 接下来展示4个主页发帖任务中，不同错误的占比，并将其数据画图。

# %%
error_distribution = pd.DataFrame(error_distribution_dict).fillna(0)
error_distribution.T
# Out:
#                                                code 0      code 101    \
# 151.106.35.202 U43_page_post_logs_tony         0.003968      0.007937
# 151.106.35.221 U43_pages_post_logs_tony        0.003793      0.010114
# 151_106_42_145GEN_R49_pages_post_logs_aidan    0.000000      0.000000
# 18U45-10 page_post_logs_aaron                  0.015385      0.007692
# b8 151.106.41.12  page_post_logs_cary          0.021220      0.000000
#
#                                                code 102      code 103    \
# 151.106.35.202 U43_page_post_logs_tony           0.000000      0.023810
# 151.106.35.221 U43_pages_post_logs_tony          0.000000      0.021492
# 151_106_42_145GEN_R49_pages_post_logs_aidan      0.001129      0.002257
# 18U45-10 page_post_logs_aaron                    0.000000      0.000000
# b8 151.106.41.12  page_post_logs_cary            0.000000      0.000000
#
#                                                code 121      code 168    \
# 151.106.35.202 U43_page_post_logs_tony           0.003968      0.359127
# 151.106.35.221 U43_pages_post_logs_tony          0.005057      0.288243
# 151_106_42_145GEN_R49_pages_post_logs_aidan      0.011287      0.091422
# 18U45-10 page_post_logs_aaron                    0.000000      0.584615
# b8 151.106.41.12  page_post_logs_cary            0.005305      0.082228
#
#                                                code 3      code 55    \
# 151.106.35.202 U43_page_post_logs_tony         0.085317     0.515873
# 151.106.35.221 U43_pages_post_logs_tony        0.021492     0.614412
# 151_106_42_145GEN_R49_pages_post_logs_aidan    0.006772     0.887133
# 18U45-10 page_post_logs_aaron                  0.015385     0.376923
# b8 151.106.41.12  page_post_logs_cary          0.000000     0.891247
#
#                                                code 81
# 151.106.35.202 U43_page_post_logs_tony          0.000000
# 151.106.35.221 U43_pages_post_logs_tony         0.035398
# 151_106_42_145GEN_R49_pages_post_logs_aidan     0.000000
# 18U45-10 page_post_logs_aaron                   0.000000
# b8 151.106.41.12  page_post_logs_cary           0.000000

# %%
error_distribution_plot = error_distribution.plot(kind='bar', figsize=(16, 8), title='distribution of error code', rot=True)

# %% [markdown]
# #### 下面看下不同错误的数量相对于发帖总数的比例，并将其数据画图。

# %%
error_distribution_to_total = pd.DataFrame(error_distribution_to_total_dict).fillna(0)
error_distribution_to_total.T
# Out:
#                                                code 0      code 101    \
# 151.106.35.202 U43_page_post_logs_tony         0.002114      0.004228
# 151.106.35.221 U43_pages_post_logs_tony        0.001794      0.004785
# 151_106_42_145GEN_R49_pages_post_logs_aidan    0.000000      0.000000
# 18U45-10 page_post_logs_aaron                  0.007937      0.003968
# b8 151.106.41.12  page_post_logs_cary          0.012365      0.000000
#
#                                                code 102      code 103    \
# 151.106.35.202 U43_page_post_logs_tony           0.000000      0.012685
# 151.106.35.221 U43_pages_post_logs_tony          0.000000      0.010167
# 151_106_42_145GEN_R49_pages_post_logs_aidan      0.000654      0.001309
# 18U45-10 page_post_logs_aaron                    0.000000      0.000000
# b8 151.106.41.12  page_post_logs_cary            0.000000      0.000000
#
#                                                code 121      code 168    \
# 151.106.35.202 U43_page_post_logs_tony           0.002114      0.191332
# 151.106.35.221 U43_pages_post_logs_tony          0.002392      0.136364
# 151_106_42_145GEN_R49_pages_post_logs_aidan      0.006545      0.053010
# 18U45-10 page_post_logs_aaron                    0.000000      0.301587
# b8 151.106.41.12  page_post_logs_cary            0.003091      0.047913
#
#                                                code 3      code 55    \
# 151.106.35.202 U43_page_post_logs_tony         0.045455     0.274841
# 151.106.35.221 U43_pages_post_logs_tony        0.010167     0.290670
# 151_106_42_145GEN_R49_pages_post_logs_aidan    0.003927     0.514398
# 18U45-10 page_post_logs_aaron                  0.007937     0.194444
# b8 151.106.41.12  page_post_logs_cary          0.000000     0.519320
#
#                                                code 81
# 151.106.35.202 U43_page_post_logs_tony          0.000000
# 151.106.35.221 U43_pages_post_logs_tony         0.016746
# 151_106_42_145GEN_R49_pages_post_logs_aidan     0.000000
# 18U45-10 page_post_logs_aaron                   0.000000
# b8 151.106.41.12  page_post_logs_cary           0.000000

# %%
error_distribution_to_total_plot = error_distribution_to_total.plot(kind='bar', figsize=(16, 8), rot=True,
                                                                    title='distribution of error code to total')

# %% [markdown]
# #### 从以上的数据分析可以看出，错误发帖量占总发帖量的占比为40%-60%之间，在所有错误发帖中数量占比最高的错误为code 55，code 55数量占总错误量的比例40%-90%之间，code 55数量相对于发帖总数的比例在20%-50%之间，其中错误占比第二高的错误为code 168，此类错误为超时错误，主要由于服务器CPU负载过高或者账号网络太差造成，此类错误可以通过优化CPU负载和账号网络降低错误比例，code 55错误为Facebook群限制Facebook主页在群里发帖和评论，从而导致的发帖错误，此错误受Facebook群的设置限制，非发帖操作能解决。
